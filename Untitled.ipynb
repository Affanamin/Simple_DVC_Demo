# %%
from src.get_data import read_params
import argparse
import mlflow
from mlflow.tracking import MlflowClient
from pprint import pprint
import joblib
import os


def log_production_model(config_path):
    config = read_params(config_path)

    mlflow_config = config["mlflow_config"]

    model_name = mlflow_config["registered_model_name"]

    remote_server_uri = mlflow_config["remote_server_uri"]

    mlflow.set_tracking_uri(remote_server_uri)

    runs = mlflow.search_runs(experiment_ids=1)
    lowest = runs["metrics.mae"].sort_values(ascending=True)[0]
    lowest_run_id = runs[runs["metrics.mae"] == lowest]["run_id"][0]

    client = MlflowClient()
    for mv in client.search_model_versions(f"name='{model_name}'"):
        mv = dict(mv)
        pprint(mv, indent=4)

#         if mv["run_id"] == lowest_run_id:
#             current_version = mv["version"]
#             logged_model = mv["source"]
#             pprint(mv, indent=4)
#             client.transition_model_version_stage(
#                 name=model_name,
#                 version=current_version,
#                 stage="Production"
#             )
#         else:
#             current_version = mv["version"]
#             client.transition_model_version_stage(
#                 name=model_name,
#                 version=current_version,
#                 stage="Staging"
#             )

#     loaded_model = mlflow.pyfunc.load_model(logged_model)

#     model_path = config["webapp_model_dir"]  # "prediction_service/model"

#     joblib.dump(loaded_model, model_path)
log_production_model("params.yaml")
# Out:
# {   'creation_timestamp': 1619441376509,
#     'current_stage': 'Staging',
#     'description': '',
#     'last_updated_timestamp': 1619608851379,
#     'name': 'ElasticNetWineModel',
#     'run_id': 'd8bd5651ec4a4a27978c80665d19c8b3',
#     'run_link': '',
#     'source': './artifacts/1/d8bd5651ec4a4a27978c80665d19c8b3/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '1'}
# {   'creation_timestamp': 1619441459681,
#     'current_stage': 'Staging',
#     'description': '',
#     'last_updated_timestamp': 1619608851502,
#     'name': 'ElasticNetWineModel',
#     'run_id': '26d868ce20ff42b9bd61316cde77774d',
#     'run_link': '',
#     'source': './artifacts/1/26d868ce20ff42b9bd61316cde77774d/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '2'}
# {   'creation_timestamp': 1619441484534,
#     'current_stage': 'Staging',
#     'description': '',
#     'last_updated_timestamp': 1619608851600,
#     'name': 'ElasticNetWineModel',
#     'run_id': '5d54402740a14952a5986ee328856c34',
#     'run_link': '',
#     'source': './artifacts/1/5d54402740a14952a5986ee328856c34/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '3'}
# {   'creation_timestamp': 1619602378094,
#     'current_stage': 'Staging',
#     'description': '',
#     'last_updated_timestamp': 1619608851687,
#     'name': 'ElasticNetWineModel',
#     'run_id': '48c4254cc3174a7fb547ad5581d63e9e',
#     'run_link': '',
#     'source': './artifacts/1/48c4254cc3174a7fb547ad5581d63e9e/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '4'}
# {   'creation_timestamp': 1619608458941,
#     'current_stage': 'Production',
#     'description': '',
#     'last_updated_timestamp': 1619608851773,
#     'name': 'ElasticNetWineModel',
#     'run_id': '4e04933855d04d73990cf941103498d6',
#     'run_link': '',
#     'source': './artifacts/1/4e04933855d04d73990cf941103498d6/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '5'}
